# %%
import sqlite3
import requests as rq

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

res = rq.get('http://127.0.0.1:8000')
items = res.json()['schedule']

data = []
for item in items:
    data.append((item['Course'], item['Section'], item['Title'], item['Professor'], item['Meeting Pattern'], 
                 item['Start Time'], item['Room'], item['Seat Capacity']))
    
data
# Out:
# [('COMP110',
#   1,
#   'COMP110 Class',
#   'Alyssa Byrnes',
#   'MW',
#   '3:35PM',
#   'university',
#   300),
#  ('COMP110',
#   2,
#   'COMP110 Class',
#   'Izzi Hinks',
#   'MWF',
#   '9:05AM',
#   'university',
#   300),
#  ('COMP110',
#   3,
#   'COMP110 Class',
#   'Izzi Hinks',
#   'TTH',
#   '8:00AM',
#   'university',
#   150),
#  ('COMP110',
#   4,
#   'COMP110 Class',
#   'Alyssa Byrnes',
#   'TTH',
#   '11:00AM',
#   'university',
#   150),
#  ('COMP116',
#   1,
#   'COMP116 Class',
#   'John Majikes',
#   'MWF',
#   '10:10AM',
#   'FB-F120',
#   None),
#  ('COMP126',
#   1,
#   'COMP126 Class',
#   'Tessa Joseph-Nicholas',
#   'MWF',
#   '8:00AM',
#   'university',
#   120),
#  ('COMP210',
#   1,
#   'COMP210 Class',
#   'Sayeed Ghani',
#   'TTH',
#   '9:30AM',
#   'university',
#   210),
#  ('COMP210',
#   2,
#   'COMP210 Class',
#   'Sayeed Ghani',
#   'MWF',
#   '8:00AM',
#   'university',
#   210),
#  ('COMP211',
#   1,
#   'COMP211 Class',
#   'Brent Munsell',
#   'TTH',
#   '8:00AM',
#   'university',
#   200),
#  ('COMP211',
#   2,
#   'COMP211 Class',
#   'Brent Munsell',
#   'TTH',
#   '9:30AM',
#   'university',
#   200),
#  ('COMP283',
#   1,
#   'COMP283/283H Class',
#   'Jack Snoeyink',
#   'TTH',
#   '12:30PM',
#   'university',
#   204),
#  ('COMP301',
#   1,
#   'COMP301 Class',
#   'Prairie Goodwin',
#   'MWF',
#   '8:00AM',
#   'university',
#   200),
#  ('COMP301',
#   2,
#   'COMP301 Class',
#   'Prairie Goodwin',
#   'MWF',
#   '11:15AM',
#   'university',
#   200),
#  ('COMP311',
#   1,
#   'COMP311 Class',
#   'Cece McMahon',
#   'MWF',
#   '8:00AM',
#   'university',
#   225),
#  ('COMP380',
#   1,
#   'COMP380 Class',
#   'Tessa Joseph-Nicholas',
#   'TTH',
#   '2:00PM',
#   'SN-0011',
#   60),
#  ('COMP380H',
#   1,
#   'COMP380H Class',
#   'Tessa Joseph-Nicholas',
#   'MWF',
#   '9:05AM',
#   'FB-F009',
#   24),
#  ('COMP421', 1, 'COMP421 Class', 'TBD', 'MWF', '2:30PM', 'university', 200),
#  ('COMP426',
#   1,
#   'COMP426 Class',
#   'Ketan Mayer-Patel',
#   'TTH',
#   '8:00AM',
#   'university',
#   200),
#  ('COMP433',
#   1,
#   'COMP433 Class',
#   'Shahriar Nirjon',
#   'MWF',
#   '10:10AM',
#   'FB-F009',
#   75),
#  ('COMP435',
#   1,
#   'COMP435 Class',
#   'Cynthia Sturton',
#   'MWF',
#   '10:10AM',
#   'SN-0014',
#   70),
#  ('COMP455',
#   1,
#   'COMP455 Class',
#   'P.S. Thiagarajan',
#   'MWF',
#   '1:25PM',
#   'university',
#   125),
#  ('COMP455',
#   2,
#   'COMP455 Class',
#   'P.S. Thiagarajan',
#   'MWF',
#   '12:20PM',
#   'university',
#   125),
#  ('COMP475', 1, 'COMP475 Class', 'Mike Reed', 'MWF', '9:05AM', 'SN-0014', 60),
#  ('COMP523',
#   1,
#   'COMP523 Class',
#   'Paul Stotts',
#   'MWF',
#   '8:00AM',
#   'SN-0011',
#   60),
#  ('COMP524',
#   1,
#   'COMP524 Class',
#   'Prasun Dewan',
#   'MWF',
#   '8:00AM',
#   'FB-F009',
#   60),
#  ('COMP530',
#   1,
#   'COMP530 Class',
#   'Donald Porter',
#   'MWF',
#   '12:20PM',
#   'SN-0014',
#   75),
#  ('COMP537',
#   1,
#   'COMP537 Class',
#   'Saba Eskandarian',
#   'MWF',
#   '2:30PM',
#   'SN-0014',
#   90),
#  ('COMP541',
#   1,
#   'COMP541 Class',
#   'Montek Singh',
#   'MWF',
#   '9:05AM',
#   'FB-F007',
#   45),
#  ('COMP541',
#   2,
#   'COMP541 Class',
#   'Cece McMahon',
#   'MWF',
#   '11:15AM',
#   'FB-F007',
#   45),
#  ('COMP545',
#   1,
#   'COMP545 Class',
#   'Samarjit Chakraborty',
#   'MWF',
#   '8:00AM',
#   'FB-F141',
#   25),
#  ('COMP550',
#   1,
#   'COMP550 Class',
#   'Kevin Sun',
#   'TTH',
#   '11:00AM',
#   'university',
#   125),
#  ('COMP550',
#   2,
#   'COMP550 Class',
#   'Kevin Sun',
#   'MWF',
#   '8:00AM',
#   'university',
#   125),
#  ('COMP562',
#   1,
#   'COMP562 Class',
#   'Jorge Silva',
#   'TTH',
#   '8:00AM',
#   'FB-F009',
#   75),
#  ('COMP581',
#   1,
#   'COMP581 Class',
#   'Daniel Szafir',
#   'MWF',
#   '8:00AM',
#   'SN-0014',
#   60),
#  ('COMP590-59',
#   59,
#   'COMP590-59 Class',
#   'Paul Stotts',
#   'TTH',
#   '9:30AM',
#   'SN-0014',
#   90),
#  ('COMP590-140',
#   140,
#   'COMP590-140 Class',
#   'Kris Jordan',
#   'TTH',
#   '11:00AM',
#   'university',
#   280),
#  ('COMP590-177',
#   177,
#   'COMP590-177 Class',
#   'Roni Sengupta',
#   'TTH',
#   '5:00PM',
#   'SN-0011',
#   60),
#  ('COMP664',
#   1,
#   'COMP664 Class',
#   'Shashank Srivastava',
#   'MWF',
#   '3:35PM',
#   'FB-F009',
#   60),
#  ('COMP737',
#   1,
#   'COMP737 Class',
#   'James Anderson',
#   'MWF',
#   '2:30PM',
#   'SN-0011',
#   30),
#  ('COMP750',
#   1,
#   'COMP750 Class',
#   'James Anderson',
#   'MWF',
#   '12:20PM',
#   'FB-F141',
#   30),
#  ('COMP755',
#   1,
#   'COMP755 Class',
#   'Junier Oliva',
#   'MWF',
#   '11:15AM',
#   'FB-F141',
#   30),
#  ('COMP775',
#   1,
#   'COMP775 Class',
#   'Marc Niethammer',
#   'MWF',
#   '1:25PM',
#   'FB-F141',
#   30),
#  ('COMP790-144',
#   144,
#   'COMP790-144 Class',
#   'Parasara Sridhar Duggirala',
#   'MW',
#   '3:35PM',
#   'FB-F141',
#   30),
#  ('COMP790-148',
#   148,
#   'COMP790-148 Class',
#   'Samarjit Chakraborty',
#   'MWF',
#   '3:35PM',
#   'SN-0115',
#   25),
#  ('COMP790-158',
#   158,
#   'COMP790-158 Class',
#   'Snigdha Chaturvedi',
#   'MW',
#   '1:25PM',
#   'SN-0115',
#   21),
#  ('COMP790-170',
#   1,
#   'COMP790-170 Class',
#   'Gedas Bertasius',
#   'MW',
#   '12:20PM',
#   'FB-F009',
#   30),
#  ('COMP790-172',
#   172,
#   'COMP790-172 Class',
#   'Danielle Szafir',
#   'TTH',
#   '8:00AM',
#   'FB-F141',
#   30),
#  ('COMP790-175',
#   175,
#   'COMP790-175 Class',
#   'Praneeth Chakravarthula',
#   'TTH',
#   '9:30AM',
#   'FB-F141',
#   30),
#  ('COMP790-178',
#   178,
#   'COMP790-178 Class',
#   'Ben Berg',
#   'MWF',
#   '8:00AM',
#   'FB-F007',
#   20),
#  ('COMP790-183',
#   183,
#   'COMP790-183 Class',
#   'Huaxiu Yao',
#   'TTH',
#   '9:30AM',
#   'SN-0011',
#   30),
#  ('COMP790-185',
#   185,
#   'COMP790-185 Class',
#   'Andrew Kwong',
#   'MWF',
#   '10:10AM',
#   'FB-F007',
#   30)]

# %%
try:
    insert_query = "INSERT INTO Courses (Course, Section, Title, Prof, MeetingPattern, Start, Room, SeatCapacity) VALUES (?, ?, ?, ?, ?, ?, ?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
mwf_periods = {
        1: {'start_time': '8:00AM', 'duration': 50},
        2: {'start_time': '9:05AM', 'duration': 50},
        3: {'start_time': '10:10AM', 'duration': 50},
        4: {'start_time': '11:15AM', 'duration': 50},
        5: {'start_time': '12:20PM', 'duration': 50},
        6: {'start_time': '1:25PM', 'duration': 50},
        7: {'start_time': '2:30PM', 'duration': 50},
        8: {'start_time': '3:35PM', 'duration': 50},
}

# TTH periods (75 minutes each)
tth_periods = {
    1: {'start_time': '8:00AM', 'duration': 75},
    2: {'start_time': '9:30AM', 'duration': 75},
    3: {'start_time': '11:00AM', 'duration': 75},
    4: {'start_time': '12:30PM', 'duration': 75},
    5: {'start_time': '2:00PM', 'duration': 75},
    6: {'start_time': '3:30PM', 'duration': 75},
    7: {'start_time': '5:00PM', 'duration': 75}
}

# MW periods (75 minutes each)
mw_periods = {
    1: {'start_time': '8:00AM', 'duration': 75},
    3: {'start_time': '10:10AM', 'duration': 75},
    5: {'start_time': '12:20PM', 'duration': 75},
    7: {'start_time': '2:30PM', 'duration': 75},
}

data2 = []
for item in tth_periods.keys():
    elt = tth_periods[item]
    data2.append(('MWF', item, elt['start_time'], elt['duration']))

for item in mwf_periods.keys():
    elt = mwf_periods[item]
    data2.append(('TTH', item, elt['start_time'], elt['duration']))

for item in mw_periods.keys():
    elt = mw_periods[item]
    data2.append(('MW', item, elt['start_time'], elt['duration']))

data2
# Out:
# [('MWF', 1, '8:00AM', 75),
#  ('MWF', 2, '9:30AM', 75),
#  ('MWF', 3, '11:00AM', 75),
#  ('MWF', 4, '12:30PM', 75),
#  ('MWF', 5, '2:00PM', 75),
#  ('MWF', 6, '3:30PM', 75),
#  ('MWF', 7, '5:00PM', 75),
#  ('TTH', 1, '8:00AM', 50),
#  ('TTH', 2, '9:05AM', 50),
#  ('TTH', 3, '10:10AM', 50),
#  ('TTH', 4, '11:15AM', 50),
#  ('TTH', 5, '12:20PM', 50),
#  ('TTH', 6, '1:25PM', 50),
#  ('TTH', 7, '2:30PM', 50),
#  ('TTH', 8, '3:35PM', 50),
#  ('MW', 1, '8:00AM', 75),
#  ('MW', 3, '10:10AM', 75),
#  ('MW', 5, '12:20PM', 75),
#  ('MW', 7, '2:30PM', 75)]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO ClassPeriods (MeetingPattern, Number, StartTime, Duration) VALUES (?, ?, ?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data2)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
profs = {
    "Montek Singh": {
        "qualified_courses": [
            "COMP541",
            "COMP572"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Tessa Joseph-Nicholas": {
        "qualified_courses": [
            "COMP126",
            "COMP380",
            "COMP380H"
        ],
        "availability": "time_slots",
        "max_classes": 3
    },
    "Ketan Mayer-Patel": {
        "qualified_courses": [
            "COMP301",
            "COMP426"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Prairie Goodwin": {
        "qualified_courses": [
            "COMP301"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Sayeed Ghani": {
        "qualified_courses": [
            "COMP210"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "P.S. Thiagarajan": {
        "qualified_courses": [
            "COMP455"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Jasleen Kaur": {
        "qualified_courses": [
            "COMP431"
        ],
        "availability": "time_slots",
        "max_classes": 0
    },
    "Saba Eskandarian": {
        "qualified_courses": [
            "COMP537",
            "COMP455",
            "COMP435",
            "COMP590",
            "COMP790"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Ron Alterovitz": {
        "qualified_courses": [
            "COMP581",
            "COMP781",
            "COMP782"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Cynthia Sturton": {
        "qualified_courses": [
            "COMP435"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Marc Niethammer": {
        "qualified_courses": [
            "COMP775"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Izzi Hinks": {
        "qualified_courses": [
            "COMP110"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Samarjit Chakraborty": {
        "qualified_courses": [
            "COMP545",
            "COMP790-148"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Donald Porter": {
        "qualified_courses": [
            "COMP530"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "John Majikes": {
        "qualified_courses": [
            "COMP421",
            "COMP550",
            "COMP116"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Alyssa Byrnes": {
        "qualified_courses": [
            "COMP110",
            "COMP116",
            "COMP210",
            "COMP283"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Gedas Bertasius": {
        "qualified_courses": [
            "COMP790-170"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Roni Sengupta": {
        "qualified_courses": [
            "COMP590-177"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Kevin Sun": {
        "qualified_courses": [
            "COMP283",
            "COMP455",
            "COMP550"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Cece McMahon": {
        "qualified_courses": [
            "COMP311",
            "COMP541"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Shahriar Nirjon": {
        "qualified_courses": [
            "COMP433"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Jack Snoeyink": {
        "qualified_courses": [
            "COMP283",
            "DATA140"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Brent Munsell": {
        "qualified_courses": [
            "COMP211",
            "COMP590",
            "COMP530",
            "COMP311",
            "COMP116"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "James Anderson": {
        "qualified_courses": [
            "COMP737",
            "COMP750"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Danielle Szafir": {
        "qualified_courses": [
            "COMP790-172"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Daniel Szafir": {
        "qualified_courses": [
            "COMP581"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Parasara Sridhar Duggirala": {
        "qualified_courses": [
            "COMP089",
            "COMP790-144"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Praneeth Chakravarthula": {
        "qualified_courses": [
            "COMP790-175"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Ben Berg": {
        "qualified_courses": [
            "COMP790-178"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Shashank Srivastava": {
        "qualified_courses": [
            "COMP664"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Snigdha Chaturvedi": {
        "qualified_courses": [
            "COMP790-158"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Huaxiu Yao": {
        "qualified_courses": [
            "COMP790-183"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Andrew Kwong": {
        "qualified_courses": [
            "COMP790-185"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Mike Reed": {
        "qualified_courses": [
            "COMP475"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Paul Stotts": {
        "qualified_courses": [
            "COMP590-59",
            "COMP523"
        ],
        "availability": "time_slots",
        "max_classes": 3
    },
    "Prasun Dewan": {
        "qualified_courses": [
            "COMP524"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Jorge Silva": {
        "qualified_courses": [
            "COMP562"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Kris Jordan": {
        "qualified_courses": [
            "COMP590-140"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Junier Oliva": {
        "qualified_courses": [
            "COMP755"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "TBD": {
        "qualified_courses": [
            "COMP421"
        ],
        "availability": "time_slots",
        "max_classes": 1
    }
}.keys()

# %%
profs = list(profs)

# %%
profs
# Out:
# ['Montek Singh',
#  'Tessa Joseph-Nicholas',
#  'Ketan Mayer-Patel',
#  'Prairie Goodwin',
#  'Sayeed Ghani',
#  'P.S. Thiagarajan',
#  'Jasleen Kaur',
#  'Saba Eskandarian',
#  'Ron Alterovitz',
#  'Cynthia Sturton',
#  'Marc Niethammer',
#  'Izzi Hinks',
#  'Samarjit Chakraborty',
#  'Donald Porter',
#  'John Majikes',
#  'Alyssa Byrnes',
#  'Gedas Bertasius',
#  'Roni Sengupta',
#  'Kevin Sun',
#  'Cece McMahon',
#  'Shahriar Nirjon',
#  'Jack Snoeyink',
#  'Brent Munsell',
#  'James Anderson',
#  'Danielle Szafir',
#  'Daniel Szafir',
#  'Parasara Sridhar Duggirala',
#  'Praneeth Chakravarthula',
#  'Ben Berg',
#  'Shashank Srivastava',
#  'Snigdha Chaturvedi',
#  'Huaxiu Yao',
#  'Andrew Kwong',
#  'Mike Reed',
#  'Paul Stotts',
#  'Prasun Dewan',
#  'Jorge Silva',
#  'Kris Jordan',
#  'Junier Oliva',
#  'TBD']

# %%
data3 = []

for prof in profs:
    for item in data2:
        data3.append((prof, item[0], item[1]))

data3
# Out:
# [('Montek Singh', 'MWF', 1),
#  ('Montek Singh', 'MWF', 2),
#  ('Montek Singh', 'MWF', 3),
#  ('Montek Singh', 'MWF', 4),
#  ('Montek Singh', 'MWF', 5),
#  ('Montek Singh', 'MWF', 6),
#  ('Montek Singh', 'MWF', 7),
#  ('Montek Singh', 'TTH', 1),
#  ('Montek Singh', 'TTH', 2),
#  ('Montek Singh', 'TTH', 3),
#  ('Montek Singh', 'TTH', 4),
#  ('Montek Singh', 'TTH', 5),
#  ('Montek Singh', 'TTH', 6),
#  ('Montek Singh', 'TTH', 7),
#  ('Montek Singh', 'TTH', 8),
#  ('Montek Singh', 'MW', 1),
#  ('Montek Singh', 'MW', 3),
#  ('Montek Singh', 'MW', 5),
#  ('Montek Singh', 'MW', 7),
#  ('Tessa Joseph-Nicholas', 'MWF', 1),
#  ('Tessa Joseph-Nicholas', 'MWF', 2),
#  ('Tessa Joseph-Nicholas', 'MWF', 3),
#  ('Tessa Joseph-Nicholas', 'MWF', 4),
#  ('Tessa Joseph-Nicholas', 'MWF', 5),
#  ('Tessa Joseph-Nicholas', 'MWF', 6),
#  ('Tessa Joseph-Nicholas', 'MWF', 7),
#  ('Tessa Joseph-Nicholas', 'TTH', 1),
#  ('Tessa Joseph-Nicholas', 'TTH', 2),
#  ('Tessa Joseph-Nicholas', 'TTH', 3),
#  ('Tessa Joseph-Nicholas', 'TTH', 4),
#  ('Tessa Joseph-Nicholas', 'TTH', 5),
#  ('Tessa Joseph-Nicholas', 'TTH', 6),
#  ('Tessa Joseph-Nicholas', 'TTH', 7),
#  ('Tessa Joseph-Nicholas', 'TTH', 8),
#  ('Tessa Joseph-Nicholas', 'MW', 1),
#  ('Tessa Joseph-Nicholas', 'MW', 3),
#  ('Tessa Joseph-Nicholas', 'MW', 5),
#  ('Tessa Joseph-Nicholas', 'MW', 7),
#  ('Ketan Mayer-Patel', 'MWF', 1),
#  ('Ketan Mayer-Patel', 'MWF', 2),
#  ('Ketan Mayer-Patel', 'MWF', 3),
#  ('Ketan Mayer-Patel', 'MWF', 4),
#  ('Ketan Mayer-Patel', 'MWF', 5),
#  ('Ketan Mayer-Patel', 'MWF', 6),
#  ('Ketan Mayer-Patel', 'MWF', 7),
#  ('Ketan Mayer-Patel', 'TTH', 1),
#  ('Ketan Mayer-Patel', 'TTH', 2),
#  ('Ketan Mayer-Patel', 'TTH', 3),
#  ('Ketan Mayer-Patel', 'TTH', 4),
#  ('Ketan Mayer-Patel', 'TTH', 5),
#  ('Ketan Mayer-Patel', 'TTH', 6),
#  ('Ketan Mayer-Patel', 'TTH', 7),
#  ('Ketan Mayer-Patel', 'TTH', 8),
#  ('Ketan Mayer-Patel', 'MW', 1),
#  ('Ketan Mayer-Patel', 'MW', 3),
#  ('Ketan Mayer-Patel', 'MW', 5),
#  ('Ketan Mayer-Patel', 'MW', 7),
#  ('Prairie Goodwin', 'MWF', 1),
#  ('Prairie Goodwin', 'MWF', 2),
#  ('Prairie Goodwin', 'MWF', 3),
#  ('Prairie Goodwin', 'MWF', 4),
#  ('Prairie Goodwin', 'MWF', 5),
#  ('Prairie Goodwin', 'MWF', 6),
#  ('Prairie Goodwin', 'MWF', 7),
#  ('Prairie Goodwin', 'TTH', 1),
#  ('Prairie Goodwin', 'TTH', 2),
#  ('Prairie Goodwin', 'TTH', 3),
#  ('Prairie Goodwin', 'TTH', 4),
#  ('Prairie Goodwin', 'TTH', 5),
#  ('Prairie Goodwin', 'TTH', 6),
#  ('Prairie Goodwin', 'TTH', 7),
#  ('Prairie Goodwin', 'TTH', 8),
#  ('Prairie Goodwin', 'MW', 1),
#  ('Prairie Goodwin', 'MW', 3),
#  ('Prairie Goodwin', 'MW', 5),
#  ('Prairie Goodwin', 'MW', 7),
#  ('Sayeed Ghani', 'MWF', 1),
#  ('Sayeed Ghani', 'MWF', 2),
#  ('Sayeed Ghani', 'MWF', 3),
#  ('Sayeed Ghani', 'MWF', 4),
#  ('Sayeed Ghani', 'MWF', 5),
#  ('Sayeed Ghani', 'MWF', 6),
#  ('Sayeed Ghani', 'MWF', 7),
#  ('Sayeed Ghani', 'TTH', 1),
#  ('Sayeed Ghani', 'TTH', 2),
#  ('Sayeed Ghani', 'TTH', 3),
#  ('Sayeed Ghani', 'TTH', 4),
#  ('Sayeed Ghani', 'TTH', 5),
#  ('Sayeed Ghani', 'TTH', 6),
#  ('Sayeed Ghani', 'TTH', 7),
#  ('Sayeed Ghani', 'TTH', 8),
#  ('Sayeed Ghani', 'MW', 1),
#  ('Sayeed Ghani', 'MW', 3),
#  ('Sayeed Ghani', 'MW', 5),
#  ('Sayeed Ghani', 'MW', 7),
#  ('P.S. Thiagarajan', 'MWF', 1),
#  ('P.S. Thiagarajan', 'MWF', 2),
#  ('P.S. Thiagarajan', 'MWF', 3),
#  ('P.S. Thiagarajan', 'MWF', 4),
#  ('P.S. Thiagarajan', 'MWF', 5),
#  ('P.S. Thiagarajan', 'MWF', 6),
#  ('P.S. Thiagarajan', 'MWF', 7),
#  ('P.S. Thiagarajan', 'TTH', 1),
#  ('P.S. Thiagarajan', 'TTH', 2),
#  ('P.S. Thiagarajan', 'TTH', 3),
#  ('P.S. Thiagarajan', 'TTH', 4),
#  ('P.S. Thiagarajan', 'TTH', 5),
#  ('P.S. Thiagarajan', 'TTH', 6),
#  ('P.S. Thiagarajan', 'TTH', 7),
#  ('P.S. Thiagarajan', 'TTH', 8),
#  ('P.S. Thiagarajan', 'MW', 1),
#  ('P.S. Thiagarajan', 'MW', 3),
#  ('P.S. Thiagarajan', 'MW', 5),
#  ('P.S. Thiagarajan', 'MW', 7),
#  ('Jasleen Kaur', 'MWF', 1),
#  ('Jasleen Kaur', 'MWF', 2),
#  ('Jasleen Kaur', 'MWF', 3),
#  ('Jasleen Kaur', 'MWF', 4),
#  ('Jasleen Kaur', 'MWF', 5),
#  ('Jasleen Kaur', 'MWF', 6),
#  ('Jasleen Kaur', 'MWF', 7),
#  ('Jasleen Kaur', 'TTH', 1),
#  ('Jasleen Kaur', 'TTH', 2),
#  ('Jasleen Kaur', 'TTH', 3),
#  ('Jasleen Kaur', 'TTH', 4),
#  ('Jasleen Kaur', 'TTH', 5),
#  ('Jasleen Kaur', 'TTH', 6),
#  ('Jasleen Kaur', 'TTH', 7),
#  ('Jasleen Kaur', 'TTH', 8),
#  ('Jasleen Kaur', 'MW', 1),
#  ('Jasleen Kaur', 'MW', 3),
#  ('Jasleen Kaur', 'MW', 5),
#  ('Jasleen Kaur', 'MW', 7),
#  ('Saba Eskandarian', 'MWF', 1),
#  ('Saba Eskandarian', 'MWF', 2),
#  ('Saba Eskandarian', 'MWF', 3),
#  ('Saba Eskandarian', 'MWF', 4),
#  ('Saba Eskandarian', 'MWF', 5),
#  ('Saba Eskandarian', 'MWF', 6),
#  ('Saba Eskandarian', 'MWF', 7),
#  ('Saba Eskandarian', 'TTH', 1),
#  ('Saba Eskandarian', 'TTH', 2),
#  ('Saba Eskandarian', 'TTH', 3),
#  ('Saba Eskandarian', 'TTH', 4),
#  ('Saba Eskandarian', 'TTH', 5),
#  ('Saba Eskandarian', 'TTH', 6),
#  ('Saba Eskandarian', 'TTH', 7),
#  ('Saba Eskandarian', 'TTH', 8),
#  ('Saba Eskandarian', 'MW', 1),
#  ('Saba Eskandarian', 'MW', 3),
#  ('Saba Eskandarian', 'MW', 5),
#  ('Saba Eskandarian', 'MW', 7),
#  ('Ron Alterovitz', 'MWF', 1),
#  ('Ron Alterovitz', 'MWF', 2),
#  ('Ron Alterovitz', 'MWF', 3),
#  ('Ron Alterovitz', 'MWF', 4),
#  ('Ron Alterovitz', 'MWF', 5),
#  ('Ron Alterovitz', 'MWF', 6),
#  ('Ron Alterovitz', 'MWF', 7),
#  ('Ron Alterovitz', 'TTH', 1),
#  ('Ron Alterovitz', 'TTH', 2),
#  ('Ron Alterovitz', 'TTH', 3),
#  ('Ron Alterovitz', 'TTH', 4),
#  ('Ron Alterovitz', 'TTH', 5),
#  ('Ron Alterovitz', 'TTH', 6),
#  ('Ron Alterovitz', 'TTH', 7),
#  ('Ron Alterovitz', 'TTH', 8),
#  ('Ron Alterovitz', 'MW', 1),
#  ('Ron Alterovitz', 'MW', 3),
#  ('Ron Alterovitz', 'MW', 5),
#  ('Ron Alterovitz', 'MW', 7),
#  ('Cynthia Sturton', 'MWF', 1),
#  ('Cynthia Sturton', 'MWF', 2),
#  ('Cynthia Sturton', 'MWF', 3),
#  ('Cynthia Sturton', 'MWF', 4),
#  ('Cynthia Sturton', 'MWF', 5),
#  ('Cynthia Sturton', 'MWF', 6),
#  ('Cynthia Sturton', 'MWF', 7),
#  ('Cynthia Sturton', 'TTH', 1),
#  ('Cynthia Sturton', 'TTH', 2),
#  ('Cynthia Sturton', 'TTH', 3),
#  ('Cynthia Sturton', 'TTH', 4),
#  ('Cynthia Sturton', 'TTH', 5),
#  ('Cynthia Sturton', 'TTH', 6),
#  ('Cynthia Sturton', 'TTH', 7),
#  ('Cynthia Sturton', 'TTH', 8),
#  ('Cynthia Sturton', 'MW', 1),
#  ('Cynthia Sturton', 'MW', 3),
#  ('Cynthia Sturton', 'MW', 5),
#  ('Cynthia Sturton', 'MW', 7),
#  ('Marc Niethammer', 'MWF', 1),
#  ('Marc Niethammer', 'MWF', 2),
#  ('Marc Niethammer', 'MWF', 3),
#  ('Marc Niethammer', 'MWF', 4),
#  ('Marc Niethammer', 'MWF', 5),
#  ('Marc Niethammer', 'MWF', 6),
#  ('Marc Niethammer', 'MWF', 7),
#  ('Marc Niethammer', 'TTH', 1),
#  ('Marc Niethammer', 'TTH', 2),
#  ('Marc Niethammer', 'TTH', 3),
#  ('Marc Niethammer', 'TTH', 4),
#  ('Marc Niethammer', 'TTH', 5),
#  ('Marc Niethammer', 'TTH', 6),
#  ('Marc Niethammer', 'TTH', 7),
#  ('Marc Niethammer', 'TTH', 8),
#  ('Marc Niethammer', 'MW', 1),
#  ('Marc Niethammer', 'MW', 3),
#  ('Marc Niethammer', 'MW', 5),
#  ('Marc Niethammer', 'MW', 7),
#  ('Izzi Hinks', 'MWF', 1),
#  ('Izzi Hinks', 'MWF', 2),
#  ('Izzi Hinks', 'MWF', 3),
#  ('Izzi Hinks', 'MWF', 4),
#  ('Izzi Hinks', 'MWF', 5),
#  ('Izzi Hinks', 'MWF', 6),
#  ('Izzi Hinks', 'MWF', 7),
#  ('Izzi Hinks', 'TTH', 1),
#  ('Izzi Hinks', 'TTH', 2),
#  ('Izzi Hinks', 'TTH', 3),
#  ('Izzi Hinks', 'TTH', 4),
#  ('Izzi Hinks', 'TTH', 5),
#  ('Izzi Hinks', 'TTH', 6),
#  ('Izzi Hinks', 'TTH', 7),
#  ('Izzi Hinks', 'TTH', 8),
#  ('Izzi Hinks', 'MW', 1),
#  ('Izzi Hinks', 'MW', 3),
#  ('Izzi Hinks', 'MW', 5),
#  ('Izzi Hinks', 'MW', 7),
#  ('Samarjit Chakraborty', 'MWF', 1),
#  ('Samarjit Chakraborty', 'MWF', 2),
#  ('Samarjit Chakraborty', 'MWF', 3),
#  ('Samarjit Chakraborty', 'MWF', 4),
#  ('Samarjit Chakraborty', 'MWF', 5),
#  ('Samarjit Chakraborty', 'MWF', 6),
#  ('Samarjit Chakraborty', 'MWF', 7),
#  ('Samarjit Chakraborty', 'TTH', 1),
#  ('Samarjit Chakraborty', 'TTH', 2),
#  ('Samarjit Chakraborty', 'TTH', 3),
#  ('Samarjit Chakraborty', 'TTH', 4),
#  ('Samarjit Chakraborty', 'TTH', 5),
#  ('Samarjit Chakraborty', 'TTH', 6),
#  ('Samarjit Chakraborty', 'TTH', 7),
#  ('Samarjit Chakraborty', 'TTH', 8),
#  ('Samarjit Chakraborty', 'MW', 1),
#  ('Samarjit Chakraborty', 'MW', 3),
#  ('Samarjit Chakraborty', 'MW', 5),
#  ('Samarjit Chakraborty', 'MW', 7),
#  ('Donald Porter', 'MWF', 1),
#  ('Donald Porter', 'MWF', 2),
#  ('Donald Porter', 'MWF', 3),
#  ('Donald Porter', 'MWF', 4),
#  ('Donald Porter', 'MWF', 5),
#  ('Donald Porter', 'MWF', 6),
#  ('Donald Porter', 'MWF', 7),
#  ('Donald Porter', 'TTH', 1),
#  ('Donald Porter', 'TTH', 2),
#  ('Donald Porter', 'TTH', 3),
#  ('Donald Porter', 'TTH', 4),
#  ('Donald Porter', 'TTH', 5),
#  ('Donald Porter', 'TTH', 6),
#  ('Donald Porter', 'TTH', 7),
#  ('Donald Porter', 'TTH', 8),
#  ('Donald Porter', 'MW', 1),
#  ('Donald Porter', 'MW', 3),
#  ('Donald Porter', 'MW', 5),
#  ('Donald Porter', 'MW', 7),
#  ('John Majikes', 'MWF', 1),
#  ('John Majikes', 'MWF', 2),
#  ('John Majikes', 'MWF', 3),
#  ('John Majikes', 'MWF', 4),
#  ('John Majikes', 'MWF', 5),
#  ('John Majikes', 'MWF', 6),
#  ('John Majikes', 'MWF', 7),
#  ('John Majikes', 'TTH', 1),
#  ('John Majikes', 'TTH', 2),
#  ('John Majikes', 'TTH', 3),
#  ('John Majikes', 'TTH', 4),
#  ('John Majikes', 'TTH', 5),
#  ('John Majikes', 'TTH', 6),
#  ('John Majikes', 'TTH', 7),
#  ('John Majikes', 'TTH', 8),
#  ('John Majikes', 'MW', 1),
#  ('John Majikes', 'MW', 3),
#  ('John Majikes', 'MW', 5),
#  ('John Majikes', 'MW', 7),
#  ('Alyssa Byrnes', 'MWF', 1),
#  ('Alyssa Byrnes', 'MWF', 2),
#  ('Alyssa Byrnes', 'MWF', 3),
#  ('Alyssa Byrnes', 'MWF', 4),
#  ('Alyssa Byrnes', 'MWF', 5),
#  ('Alyssa Byrnes', 'MWF', 6),
#  ('Alyssa Byrnes', 'MWF', 7),
#  ('Alyssa Byrnes', 'TTH', 1),
#  ('Alyssa Byrnes', 'TTH', 2),
#  ('Alyssa Byrnes', 'TTH', 3),
#  ('Alyssa Byrnes', 'TTH', 4),
#  ('Alyssa Byrnes', 'TTH', 5),
#  ('Alyssa Byrnes', 'TTH', 6),
#  ('Alyssa Byrnes', 'TTH', 7),
#  ('Alyssa Byrnes', 'TTH', 8),
#  ('Alyssa Byrnes', 'MW', 1),
#  ('Alyssa Byrnes', 'MW', 3),
#  ('Alyssa Byrnes', 'MW', 5),
#  ('Alyssa Byrnes', 'MW', 7),
#  ('Gedas Bertasius', 'MWF', 1),
#  ('Gedas Bertasius', 'MWF', 2),
#  ('Gedas Bertasius', 'MWF', 3),
#  ('Gedas Bertasius', 'MWF', 4),
#  ('Gedas Bertasius', 'MWF', 5),
#  ('Gedas Bertasius', 'MWF', 6),
#  ('Gedas Bertasius', 'MWF', 7),
#  ('Gedas Bertasius', 'TTH', 1),
#  ('Gedas Bertasius', 'TTH', 2),
#  ('Gedas Bertasius', 'TTH', 3),
#  ('Gedas Bertasius', 'TTH', 4),
#  ('Gedas Bertasius', 'TTH', 5),
#  ('Gedas Bertasius', 'TTH', 6),
#  ('Gedas Bertasius', 'TTH', 7),
#  ('Gedas Bertasius', 'TTH', 8),
#  ('Gedas Bertasius', 'MW', 1),
#  ('Gedas Bertasius', 'MW', 3),
#  ('Gedas Bertasius', 'MW', 5),
#  ('Gedas Bertasius', 'MW', 7),
#  ('Roni Sengupta', 'MWF', 1),
#  ('Roni Sengupta', 'MWF', 2),
#  ('Roni Sengupta', 'MWF', 3),
#  ('Roni Sengupta', 'MWF', 4),
#  ('Roni Sengupta', 'MWF', 5),
#  ('Roni Sengupta', 'MWF', 6),
#  ('Roni Sengupta', 'MWF', 7),
#  ('Roni Sengupta', 'TTH', 1),
#  ('Roni Sengupta', 'TTH', 2),
#  ('Roni Sengupta', 'TTH', 3),
#  ('Roni Sengupta', 'TTH', 4),
#  ('Roni Sengupta', 'TTH', 5),
#  ('Roni Sengupta', 'TTH', 6),
#  ('Roni Sengupta', 'TTH', 7),
#  ('Roni Sengupta', 'TTH', 8),
#  ('Roni Sengupta', 'MW', 1),
#  ('Roni Sengupta', 'MW', 3),
#  ('Roni Sengupta', 'MW', 5),
#  ('Roni Sengupta', 'MW', 7),
#  ('Kevin Sun', 'MWF', 1),
#  ('Kevin Sun', 'MWF', 2),
#  ('Kevin Sun', 'MWF', 3),
#  ('Kevin Sun', 'MWF', 4),
#  ('Kevin Sun', 'MWF', 5),
#  ('Kevin Sun', 'MWF', 6),
#  ('Kevin Sun', 'MWF', 7),
#  ('Kevin Sun', 'TTH', 1),
#  ('Kevin Sun', 'TTH', 2),
#  ('Kevin Sun', 'TTH', 3),
#  ('Kevin Sun', 'TTH', 4),
#  ('Kevin Sun', 'TTH', 5),
#  ('Kevin Sun', 'TTH', 6),
#  ('Kevin Sun', 'TTH', 7),
#  ('Kevin Sun', 'TTH', 8),
#  ('Kevin Sun', 'MW', 1),
#  ('Kevin Sun', 'MW', 3),
#  ('Kevin Sun', 'MW', 5),
#  ('Kevin Sun', 'MW', 7),
#  ('Cece McMahon', 'MWF', 1),
#  ('Cece McMahon', 'MWF', 2),
#  ('Cece McMahon', 'MWF', 3),
#  ('Cece McMahon', 'MWF', 4),
#  ('Cece McMahon', 'MWF', 5),
#  ('Cece McMahon', 'MWF', 6),
#  ('Cece McMahon', 'MWF', 7),
#  ('Cece McMahon', 'TTH', 1),
#  ('Cece McMahon', 'TTH', 2),
#  ('Cece McMahon', 'TTH', 3),
#  ('Cece McMahon', 'TTH', 4),
#  ('Cece McMahon', 'TTH', 5),
#  ('Cece McMahon', 'TTH', 6),
#  ('Cece McMahon', 'TTH', 7),
#  ('Cece McMahon', 'TTH', 8),
#  ('Cece McMahon', 'MW', 1),
#  ('Cece McMahon', 'MW', 3),
#  ('Cece McMahon', 'MW', 5),
#  ('Cece McMahon', 'MW', 7),
#  ('Shahriar Nirjon', 'MWF', 1),
#  ('Shahriar Nirjon', 'MWF', 2),
#  ('Shahriar Nirjon', 'MWF', 3),
#  ('Shahriar Nirjon', 'MWF', 4),
#  ('Shahriar Nirjon', 'MWF', 5),
#  ('Shahriar Nirjon', 'MWF', 6),
#  ('Shahriar Nirjon', 'MWF', 7),
#  ('Shahriar Nirjon', 'TTH', 1),
#  ('Shahriar Nirjon', 'TTH', 2),
#  ('Shahriar Nirjon', 'TTH', 3),
#  ('Shahriar Nirjon', 'TTH', 4),
#  ('Shahriar Nirjon', 'TTH', 5),
#  ('Shahriar Nirjon', 'TTH', 6),
#  ('Shahriar Nirjon', 'TTH', 7),
#  ('Shahriar Nirjon', 'TTH', 8),
#  ('Shahriar Nirjon', 'MW', 1),
#  ('Shahriar Nirjon', 'MW', 3),
#  ('Shahriar Nirjon', 'MW', 5),
#  ('Shahriar Nirjon', 'MW', 7),
#  ('Jack Snoeyink', 'MWF', 1),
#  ('Jack Snoeyink', 'MWF', 2),
#  ('Jack Snoeyink', 'MWF', 3),
#  ('Jack Snoeyink', 'MWF', 4),
#  ('Jack Snoeyink', 'MWF', 5),
#  ('Jack Snoeyink', 'MWF', 6),
#  ('Jack Snoeyink', 'MWF', 7),
#  ('Jack Snoeyink', 'TTH', 1),
#  ('Jack Snoeyink', 'TTH', 2),
#  ('Jack Snoeyink', 'TTH', 3),
#  ('Jack Snoeyink', 'TTH', 4),
#  ('Jack Snoeyink', 'TTH', 5),
#  ('Jack Snoeyink', 'TTH', 6),
#  ('Jack Snoeyink', 'TTH', 7),
#  ('Jack Snoeyink', 'TTH', 8),
#  ('Jack Snoeyink', 'MW', 1),
#  ('Jack Snoeyink', 'MW', 3),
#  ('Jack Snoeyink', 'MW', 5),
#  ('Jack Snoeyink', 'MW', 7),
#  ('Brent Munsell', 'MWF', 1),
#  ('Brent Munsell', 'MWF', 2),
#  ('Brent Munsell', 'MWF', 3),
#  ('Brent Munsell', 'MWF', 4),
#  ('Brent Munsell', 'MWF', 5),
#  ('Brent Munsell', 'MWF', 6),
#  ('Brent Munsell', 'MWF', 7),
#  ('Brent Munsell', 'TTH', 1),
#  ('Brent Munsell', 'TTH', 2),
#  ('Brent Munsell', 'TTH', 3),
#  ('Brent Munsell', 'TTH', 4),
#  ('Brent Munsell', 'TTH', 5),
#  ('Brent Munsell', 'TTH', 6),
#  ('Brent Munsell', 'TTH', 7),
#  ('Brent Munsell', 'TTH', 8),
#  ('Brent Munsell', 'MW', 1),
#  ('Brent Munsell', 'MW', 3),
#  ('Brent Munsell', 'MW', 5),
#  ('Brent Munsell', 'MW', 7),
#  ('James Anderson', 'MWF', 1),
#  ('James Anderson', 'MWF', 2),
#  ('James Anderson', 'MWF', 3),
#  ('James Anderson', 'MWF', 4),
#  ('James Anderson', 'MWF', 5),
#  ('James Anderson', 'MWF', 6),
#  ('James Anderson', 'MWF', 7),
#  ('James Anderson', 'TTH', 1),
#  ('James Anderson', 'TTH', 2),
#  ('James Anderson', 'TTH', 3),
#  ('James Anderson', 'TTH', 4),
#  ('James Anderson', 'TTH', 5),
#  ('James Anderson', 'TTH', 6),
#  ('James Anderson', 'TTH', 7),
#  ('James Anderson', 'TTH', 8),
#  ('James Anderson', 'MW', 1),
#  ('James Anderson', 'MW', 3),
#  ('James Anderson', 'MW', 5),
#  ('James Anderson', 'MW', 7),
#  ('Danielle Szafir', 'MWF', 1),
#  ('Danielle Szafir', 'MWF', 2),
#  ('Danielle Szafir', 'MWF', 3),
#  ('Danielle Szafir', 'MWF', 4),
#  ('Danielle Szafir', 'MWF', 5),
#  ('Danielle Szafir', 'MWF', 6),
#  ('Danielle Szafir', 'MWF', 7),
#  ('Danielle Szafir', 'TTH', 1),
#  ('Danielle Szafir', 'TTH', 2),
#  ('Danielle Szafir', 'TTH', 3),
#  ('Danielle Szafir', 'TTH', 4),
#  ('Danielle Szafir', 'TTH', 5),
#  ('Danielle Szafir', 'TTH', 6),
#  ('Danielle Szafir', 'TTH', 7),
#  ('Danielle Szafir', 'TTH', 8),
#  ('Danielle Szafir', 'MW', 1),
#  ('Danielle Szafir', 'MW', 3),
#  ('Danielle Szafir', 'MW', 5),
#  ('Danielle Szafir', 'MW', 7),
#  ('Daniel Szafir', 'MWF', 1),
#  ('Daniel Szafir', 'MWF', 2),
#  ('Daniel Szafir', 'MWF', 3),
#  ('Daniel Szafir', 'MWF', 4),
#  ('Daniel Szafir', 'MWF', 5),
#  ('Daniel Szafir', 'MWF', 6),
#  ('Daniel Szafir', 'MWF', 7),
#  ('Daniel Szafir', 'TTH', 1),
#  ('Daniel Szafir', 'TTH', 2),
#  ('Daniel Szafir', 'TTH', 3),
#  ('Daniel Szafir', 'TTH', 4),
#  ('Daniel Szafir', 'TTH', 5),
#  ('Daniel Szafir', 'TTH', 6),
#  ('Daniel Szafir', 'TTH', 7),
#  ('Daniel Szafir', 'TTH', 8),
#  ('Daniel Szafir', 'MW', 1),
#  ('Daniel Szafir', 'MW', 3),
#  ('Daniel Szafir', 'MW', 5),
#  ('Daniel Szafir', 'MW', 7),
#  ('Parasara Sridhar Duggirala', 'MWF', 1),
#  ('Parasara Sridhar Duggirala', 'MWF', 2),
#  ('Parasara Sridhar Duggirala', 'MWF', 3),
#  ('Parasara Sridhar Duggirala', 'MWF', 4),
#  ('Parasara Sridhar Duggirala', 'MWF', 5),
#  ('Parasara Sridhar Duggirala', 'MWF', 6),
#  ('Parasara Sridhar Duggirala', 'MWF', 7),
#  ('Parasara Sridhar Duggirala', 'TTH', 1),
#  ('Parasara Sridhar Duggirala', 'TTH', 2),
#  ('Parasara Sridhar Duggirala', 'TTH', 3),
#  ('Parasara Sridhar Duggirala', 'TTH', 4),
#  ('Parasara Sridhar Duggirala', 'TTH', 5),
#  ('Parasara Sridhar Duggirala', 'TTH', 6),
#  ('Parasara Sridhar Duggirala', 'TTH', 7),
#  ('Parasara Sridhar Duggirala', 'TTH', 8),
#  ('Parasara Sridhar Duggirala', 'MW', 1),
#  ('Parasara Sridhar Duggirala', 'MW', 3),
#  ('Parasara Sridhar Duggirala', 'MW', 5),
#  ('Parasara Sridhar Duggirala', 'MW', 7),
#  ('Praneeth Chakravarthula', 'MWF', 1),
#  ('Praneeth Chakravarthula', 'MWF', 2),
#  ('Praneeth Chakravarthula', 'MWF', 3),
#  ('Praneeth Chakravarthula', 'MWF', 4),
#  ('Praneeth Chakravarthula', 'MWF', 5),
#  ('Praneeth Chakravarthula', 'MWF', 6),
#  ('Praneeth Chakravarthula', 'MWF', 7),
#  ('Praneeth Chakravarthula', 'TTH', 1),
#  ('Praneeth Chakravarthula', 'TTH', 2),
#  ('Praneeth Chakravarthula', 'TTH', 3),
#  ('Praneeth Chakravarthula', 'TTH', 4),
#  ('Praneeth Chakravarthula', 'TTH', 5),
#  ('Praneeth Chakravarthula', 'TTH', 6),
#  ('Praneeth Chakravarthula', 'TTH', 7),
#  ('Praneeth Chakravarthula', 'TTH', 8),
#  ('Praneeth Chakravarthula', 'MW', 1),
#  ('Praneeth Chakravarthula', 'MW', 3),
#  ('Praneeth Chakravarthula', 'MW', 5),
#  ('Praneeth Chakravarthula', 'MW', 7),
#  ('Ben Berg', 'MWF', 1),
#  ('Ben Berg', 'MWF', 2),
#  ('Ben Berg', 'MWF', 3),
#  ('Ben Berg', 'MWF', 4),
#  ('Ben Berg', 'MWF', 5),
#  ('Ben Berg', 'MWF', 6),
#  ('Ben Berg', 'MWF', 7),
#  ('Ben Berg', 'TTH', 1),
#  ('Ben Berg', 'TTH', 2),
#  ('Ben Berg', 'TTH', 3),
#  ('Ben Berg', 'TTH', 4),
#  ('Ben Berg', 'TTH', 5),
#  ('Ben Berg', 'TTH', 6),
#  ('Ben Berg', 'TTH', 7),
#  ('Ben Berg', 'TTH', 8),
#  ('Ben Berg', 'MW', 1),
#  ('Ben Berg', 'MW', 3),
#  ('Ben Berg', 'MW', 5),
#  ('Ben Berg', 'MW', 7),
#  ('Shashank Srivastava', 'MWF', 1),
#  ('Shashank Srivastava', 'MWF', 2),
#  ('Shashank Srivastava', 'MWF', 3),
#  ('Shashank Srivastava', 'MWF', 4),
#  ('Shashank Srivastava', 'MWF', 5),
#  ('Shashank Srivastava', 'MWF', 6),
#  ('Shashank Srivastava', 'MWF', 7),
#  ('Shashank Srivastava', 'TTH', 1),
#  ('Shashank Srivastava', 'TTH', 2),
#  ('Shashank Srivastava', 'TTH', 3),
#  ('Shashank Srivastava', 'TTH', 4),
#  ('Shashank Srivastava', 'TTH', 5),
#  ('Shashank Srivastava', 'TTH', 6),
#  ('Shashank Srivastava', 'TTH', 7),
#  ('Shashank Srivastava', 'TTH', 8),
#  ('Shashank Srivastava', 'MW', 1),
#  ('Shashank Srivastava', 'MW', 3),
#  ('Shashank Srivastava', 'MW', 5),
#  ('Shashank Srivastava', 'MW', 7),
#  ('Snigdha Chaturvedi', 'MWF', 1),
#  ('Snigdha Chaturvedi', 'MWF', 2),
#  ('Snigdha Chaturvedi', 'MWF', 3),
#  ('Snigdha Chaturvedi', 'MWF', 4),
#  ('Snigdha Chaturvedi', 'MWF', 5),
#  ('Snigdha Chaturvedi', 'MWF', 6),
#  ('Snigdha Chaturvedi', 'MWF', 7),
#  ('Snigdha Chaturvedi', 'TTH', 1),
#  ('Snigdha Chaturvedi', 'TTH', 2),
#  ('Snigdha Chaturvedi', 'TTH', 3),
#  ('Snigdha Chaturvedi', 'TTH', 4),
#  ('Snigdha Chaturvedi', 'TTH', 5),
#  ('Snigdha Chaturvedi', 'TTH', 6),
#  ('Snigdha Chaturvedi', 'TTH', 7),
#  ('Snigdha Chaturvedi', 'TTH', 8),
#  ('Snigdha Chaturvedi', 'MW', 1),
#  ('Snigdha Chaturvedi', 'MW', 3),
#  ('Snigdha Chaturvedi', 'MW', 5),
#  ('Snigdha Chaturvedi', 'MW', 7),
#  ('Huaxiu Yao', 'MWF', 1),
#  ('Huaxiu Yao', 'MWF', 2),
#  ('Huaxiu Yao', 'MWF', 3),
#  ('Huaxiu Yao', 'MWF', 4),
#  ('Huaxiu Yao', 'MWF', 5),
#  ('Huaxiu Yao', 'MWF', 6),
#  ('Huaxiu Yao', 'MWF', 7),
#  ('Huaxiu Yao', 'TTH', 1),
#  ('Huaxiu Yao', 'TTH', 2),
#  ('Huaxiu Yao', 'TTH', 3),
#  ('Huaxiu Yao', 'TTH', 4),
#  ('Huaxiu Yao', 'TTH', 5),
#  ('Huaxiu Yao', 'TTH', 6),
#  ('Huaxiu Yao', 'TTH', 7),
#  ('Huaxiu Yao', 'TTH', 8),
#  ('Huaxiu Yao', 'MW', 1),
#  ('Huaxiu Yao', 'MW', 3),
#  ('Huaxiu Yao', 'MW', 5),
#  ('Huaxiu Yao', 'MW', 7),
#  ('Andrew Kwong', 'MWF', 1),
#  ('Andrew Kwong', 'MWF', 2),
#  ('Andrew Kwong', 'MWF', 3),
#  ('Andrew Kwong', 'MWF', 4),
#  ('Andrew Kwong', 'MWF', 5),
#  ('Andrew Kwong', 'MWF', 6),
#  ('Andrew Kwong', 'MWF', 7),
#  ('Andrew Kwong', 'TTH', 1),
#  ('Andrew Kwong', 'TTH', 2),
#  ('Andrew Kwong', 'TTH', 3),
#  ('Andrew Kwong', 'TTH', 4),
#  ('Andrew Kwong', 'TTH', 5),
#  ('Andrew Kwong', 'TTH', 6),
#  ('Andrew Kwong', 'TTH', 7),
#  ('Andrew Kwong', 'TTH', 8),
#  ('Andrew Kwong', 'MW', 1),
#  ('Andrew Kwong', 'MW', 3),
#  ('Andrew Kwong', 'MW', 5),
#  ('Andrew Kwong', 'MW', 7),
#  ('Mike Reed', 'MWF', 1),
#  ('Mike Reed', 'MWF', 2),
#  ('Mike Reed', 'MWF', 3),
#  ('Mike Reed', 'MWF', 4),
#  ('Mike Reed', 'MWF', 5),
#  ('Mike Reed', 'MWF', 6),
#  ('Mike Reed', 'MWF', 7),
#  ('Mike Reed', 'TTH', 1),
#  ('Mike Reed', 'TTH', 2),
#  ('Mike Reed', 'TTH', 3),
#  ('Mike Reed', 'TTH', 4),
#  ('Mike Reed', 'TTH', 5),
#  ('Mike Reed', 'TTH', 6),
#  ('Mike Reed', 'TTH', 7),
#  ('Mike Reed', 'TTH', 8),
#  ('Mike Reed', 'MW', 1),
#  ('Mike Reed', 'MW', 3),
#  ('Mike Reed', 'MW', 5),
#  ('Mike Reed', 'MW', 7),
#  ('Paul Stotts', 'MWF', 1),
#  ('Paul Stotts', 'MWF', 2),
#  ('Paul Stotts', 'MWF', 3),
#  ('Paul Stotts', 'MWF', 4),
#  ('Paul Stotts', 'MWF', 5),
#  ('Paul Stotts', 'MWF', 6),
#  ('Paul Stotts', 'MWF', 7),
#  ('Paul Stotts', 'TTH', 1),
#  ('Paul Stotts', 'TTH', 2),
#  ('Paul Stotts', 'TTH', 3),
#  ('Paul Stotts', 'TTH', 4),
#  ('Paul Stotts', 'TTH', 5),
#  ('Paul Stotts', 'TTH', 6),
#  ('Paul Stotts', 'TTH', 7),
#  ('Paul Stotts', 'TTH', 8),
#  ('Paul Stotts', 'MW', 1),
#  ('Paul Stotts', 'MW', 3),
#  ('Paul Stotts', 'MW', 5),
#  ('Paul Stotts', 'MW', 7),
#  ('Prasun Dewan', 'MWF', 1),
#  ('Prasun Dewan', 'MWF', 2),
#  ('Prasun Dewan', 'MWF', 3),
#  ('Prasun Dewan', 'MWF', 4),
#  ('Prasun Dewan', 'MWF', 5),
#  ('Prasun Dewan', 'MWF', 6),
#  ('Prasun Dewan', 'MWF', 7),
#  ('Prasun Dewan', 'TTH', 1),
#  ('Prasun Dewan', 'TTH', 2),
#  ('Prasun Dewan', 'TTH', 3),
#  ('Prasun Dewan', 'TTH', 4),
#  ('Prasun Dewan', 'TTH', 5),
#  ('Prasun Dewan', 'TTH', 6),
#  ('Prasun Dewan', 'TTH', 7),
#  ('Prasun Dewan', 'TTH', 8),
#  ('Prasun Dewan', 'MW', 1),
#  ('Prasun Dewan', 'MW', 3),
#  ('Prasun Dewan', 'MW', 5),
#  ('Prasun Dewan', 'MW', 7),
#  ('Jorge Silva', 'MWF', 1),
#  ('Jorge Silva', 'MWF', 2),
#  ('Jorge Silva', 'MWF', 3),
#  ('Jorge Silva', 'MWF', 4),
#  ('Jorge Silva', 'MWF', 5),
#  ('Jorge Silva', 'MWF', 6),
#  ('Jorge Silva', 'MWF', 7),
#  ('Jorge Silva', 'TTH', 1),
#  ('Jorge Silva', 'TTH', 2),
#  ('Jorge Silva', 'TTH', 3),
#  ('Jorge Silva', 'TTH', 4),
#  ('Jorge Silva', 'TTH', 5),
#  ('Jorge Silva', 'TTH', 6),
#  ('Jorge Silva', 'TTH', 7),
#  ('Jorge Silva', 'TTH', 8),
#  ('Jorge Silva', 'MW', 1),
#  ('Jorge Silva', 'MW', 3),
#  ('Jorge Silva', 'MW', 5),
#  ('Jorge Silva', 'MW', 7),
#  ('Kris Jordan', 'MWF', 1),
#  ('Kris Jordan', 'MWF', 2),
#  ('Kris Jordan', 'MWF', 3),
#  ('Kris Jordan', 'MWF', 4),
#  ('Kris Jordan', 'MWF', 5),
#  ('Kris Jordan', 'MWF', 6),
#  ('Kris Jordan', 'MWF', 7),
#  ('Kris Jordan', 'TTH', 1),
#  ('Kris Jordan', 'TTH', 2),
#  ('Kris Jordan', 'TTH', 3),
#  ('Kris Jordan', 'TTH', 4),
#  ('Kris Jordan', 'TTH', 5),
#  ('Kris Jordan', 'TTH', 6),
#  ('Kris Jordan', 'TTH', 7),
#  ('Kris Jordan', 'TTH', 8),
#  ('Kris Jordan', 'MW', 1),
#  ('Kris Jordan', 'MW', 3),
#  ('Kris Jordan', 'MW', 5),
#  ('Kris Jordan', 'MW', 7),
#  ('Junier Oliva', 'MWF', 1),
#  ('Junier Oliva', 'MWF', 2),
#  ('Junier Oliva', 'MWF', 3),
#  ('Junier Oliva', 'MWF', 4),
#  ('Junier Oliva', 'MWF', 5),
#  ('Junier Oliva', 'MWF', 6),
#  ('Junier Oliva', 'MWF', 7),
#  ('Junier Oliva', 'TTH', 1),
#  ('Junier Oliva', 'TTH', 2),
#  ('Junier Oliva', 'TTH', 3),
#  ('Junier Oliva', 'TTH', 4),
#  ('Junier Oliva', 'TTH', 5),
#  ('Junier Oliva', 'TTH', 6),
#  ('Junier Oliva', 'TTH', 7),
#  ('Junier Oliva', 'TTH', 8),
#  ('Junier Oliva', 'MW', 1),
#  ('Junier Oliva', 'MW', 3),
#  ('Junier Oliva', 'MW', 5),
#  ('Junier Oliva', 'MW', 7),
#  ('TBD', 'MWF', 1),
#  ('TBD', 'MWF', 2),
#  ('TBD', 'MWF', 3),
#  ('TBD', 'MWF', 4),
#  ('TBD', 'MWF', 5),
#  ('TBD', 'MWF', 6),
#  ('TBD', 'MWF', 7),
#  ('TBD', 'TTH', 1),
#  ('TBD', 'TTH', 2),
#  ('TBD', 'TTH', 3),
#  ('TBD', 'TTH', 4),
#  ('TBD', 'TTH', 5),
#  ('TBD', 'TTH', 6),
#  ('TBD', 'TTH', 7),
#  ('TBD', 'TTH', 8),
#  ('TBD', 'MW', 1),
#  ('TBD', 'MW', 3),
#  ('TBD', 'MW', 5),
#  ('TBD', 'MW', 7)]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO Availability (Prof, AvailableMP, AvailablePeriod) VALUES (?, ?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data3)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
data4 = []

prof_qs = {
    "Montek Singh": {
        "qualified_courses": [
            "COMP541",
            "COMP572"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Tessa Joseph-Nicholas": {
        "qualified_courses": [
            "COMP126",
            "COMP380",
            "COMP380H"
        ],
        "availability": "time_slots",
        "max_classes": 3
    },
    "Ketan Mayer-Patel": {
        "qualified_courses": [
            "COMP301",
            "COMP426"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Prairie Goodwin": {
        "qualified_courses": [
            "COMP301"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Sayeed Ghani": {
        "qualified_courses": [
            "COMP210"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "P.S. Thiagarajan": {
        "qualified_courses": [
            "COMP455"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Jasleen Kaur": {
        "qualified_courses": [
            "COMP431"
        ],
        "availability": "time_slots",
        "max_classes": 0
    },
    "Saba Eskandarian": {
        "qualified_courses": [
            "COMP537",
            "COMP455",
            "COMP435",
            "COMP590",
            "COMP790"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Ron Alterovitz": {
        "qualified_courses": [
            "COMP581",
            "COMP781",
            "COMP782"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Cynthia Sturton": {
        "qualified_courses": [
            "COMP435"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Marc Niethammer": {
        "qualified_courses": [
            "COMP775"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Izzi Hinks": {
        "qualified_courses": [
            "COMP110"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Samarjit Chakraborty": {
        "qualified_courses": [
            "COMP545",
            "COMP790-148"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Donald Porter": {
        "qualified_courses": [
            "COMP530"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "John Majikes": {
        "qualified_courses": [
            "COMP421",
            "COMP550",
            "COMP116"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Alyssa Byrnes": {
        "qualified_courses": [
            "COMP110",
            "COMP116",
            "COMP210",
            "COMP283"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Gedas Bertasius": {
        "qualified_courses": [
            "COMP790-170"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Roni Sengupta": {
        "qualified_courses": [
            "COMP590-177"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Kevin Sun": {
        "qualified_courses": [
            "COMP283",
            "COMP455",
            "COMP550"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Cece McMahon": {
        "qualified_courses": [
            "COMP311",
            "COMP541"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Shahriar Nirjon": {
        "qualified_courses": [
            "COMP433"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Jack Snoeyink": {
        "qualified_courses": [
            "COMP283",
            "DATA140"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Brent Munsell": {
        "qualified_courses": [
            "COMP211",
            "COMP590",
            "COMP530",
            "COMP311",
            "COMP116"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "James Anderson": {
        "qualified_courses": [
            "COMP737",
            "COMP750"
        ],
        "availability": "time_slots",
        "max_classes": 2
    },
    "Danielle Szafir": {
        "qualified_courses": [
            "COMP790-172"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Daniel Szafir": {
        "qualified_courses": [
            "COMP581"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Parasara Sridhar Duggirala": {
        "qualified_courses": [
            "COMP089",
            "COMP790-144"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Praneeth Chakravarthula": {
        "qualified_courses": [
            "COMP790-175"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Ben Berg": {
        "qualified_courses": [
            "COMP790-178"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Shashank Srivastava": {
        "qualified_courses": [
            "COMP664"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Snigdha Chaturvedi": {
        "qualified_courses": [
            "COMP790-158"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Huaxiu Yao": {
        "qualified_courses": [
            "COMP790-183"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Andrew Kwong": {
        "qualified_courses": [
            "COMP790-185"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Mike Reed": {
        "qualified_courses": [
            "COMP475"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Paul Stotts": {
        "qualified_courses": [
            "COMP590-59",
            "COMP523"
        ],
        "availability": "time_slots",
        "max_classes": 3
    },
    "Prasun Dewan": {
        "qualified_courses": [
            "COMP524"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Jorge Silva": {
        "qualified_courses": [
            "COMP562"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Kris Jordan": {
        "qualified_courses": [
            "COMP590-140"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "Junier Oliva": {
        "qualified_courses": [
            "COMP755"
        ],
        "availability": "time_slots",
        "max_classes": 1
    },
    "TBD": {
        "qualified_courses": [
            "COMP421"
        ],
        "availability": "time_slots",
        "max_classes": 1
    }
}

profs = prof_qs.keys()

# %%
profs = list(profs)
profs
# Out:
# ['Montek Singh',
#  'Tessa Joseph-Nicholas',
#  'Ketan Mayer-Patel',
#  'Prairie Goodwin',
#  'Sayeed Ghani',
#  'P.S. Thiagarajan',
#  'Jasleen Kaur',
#  'Saba Eskandarian',
#  'Ron Alterovitz',
#  'Cynthia Sturton',
#  'Marc Niethammer',
#  'Izzi Hinks',
#  'Samarjit Chakraborty',
#  'Donald Porter',
#  'John Majikes',
#  'Alyssa Byrnes',
#  'Gedas Bertasius',
#  'Roni Sengupta',
#  'Kevin Sun',
#  'Cece McMahon',
#  'Shahriar Nirjon',
#  'Jack Snoeyink',
#  'Brent Munsell',
#  'James Anderson',
#  'Danielle Szafir',
#  'Daniel Szafir',
#  'Parasara Sridhar Duggirala',
#  'Praneeth Chakravarthula',
#  'Ben Berg',
#  'Shashank Srivastava',
#  'Snigdha Chaturvedi',
#  'Huaxiu Yao',
#  'Andrew Kwong',
#  'Mike Reed',
#  'Paul Stotts',
#  'Prasun Dewan',
#  'Jorge Silva',
#  'Kris Jordan',
#  'Junier Oliva',
#  'TBD']

# %%
for prof in profs:
    q_course = prof_qs[prof]['qualified_courses']
    for course in q_course:
        if(course[0:4] == 'COMP'):
            data4.append((prof, course))

# %%
data4
# Out:
# [('Montek Singh', 'COMP541'),
#  ('Montek Singh', 'COMP572'),
#  ('Tessa Joseph-Nicholas', 'COMP126'),
#  ('Tessa Joseph-Nicholas', 'COMP380'),
#  ('Tessa Joseph-Nicholas', 'COMP380H'),
#  ('Ketan Mayer-Patel', 'COMP301'),
#  ('Ketan Mayer-Patel', 'COMP426'),
#  ('Prairie Goodwin', 'COMP301'),
#  ('Sayeed Ghani', 'COMP210'),
#  ('P.S. Thiagarajan', 'COMP455'),
#  ('Jasleen Kaur', 'COMP431'),
#  ('Saba Eskandarian', 'COMP537'),
#  ('Saba Eskandarian', 'COMP455'),
#  ('Saba Eskandarian', 'COMP435'),
#  ('Saba Eskandarian', 'COMP590'),
#  ('Saba Eskandarian', 'COMP790'),
#  ('Ron Alterovitz', 'COMP581'),
#  ('Ron Alterovitz', 'COMP781'),
#  ('Ron Alterovitz', 'COMP782'),
#  ('Cynthia Sturton', 'COMP435'),
#  ('Marc Niethammer', 'COMP775'),
#  ('Izzi Hinks', 'COMP110'),
#  ('Samarjit Chakraborty', 'COMP545'),
#  ('Samarjit Chakraborty', 'COMP790-148'),
#  ('Donald Porter', 'COMP530'),
#  ('John Majikes', 'COMP421'),
#  ('John Majikes', 'COMP550'),
#  ('John Majikes', 'COMP116'),
#  ('Alyssa Byrnes', 'COMP110'),
#  ('Alyssa Byrnes', 'COMP116'),
#  ('Alyssa Byrnes', 'COMP210'),
#  ('Alyssa Byrnes', 'COMP283'),
#  ('Gedas Bertasius', 'COMP790-170'),
#  ('Roni Sengupta', 'COMP590-177'),
#  ('Kevin Sun', 'COMP283'),
#  ('Kevin Sun', 'COMP455'),
#  ('Kevin Sun', 'COMP550'),
#  ('Cece McMahon', 'COMP311'),
#  ('Cece McMahon', 'COMP541'),
#  ('Shahriar Nirjon', 'COMP433'),
#  ('Jack Snoeyink', 'COMP283'),
#  ('Brent Munsell', 'COMP211'),
#  ('Brent Munsell', 'COMP590'),
#  ('Brent Munsell', 'COMP530'),
#  ('Brent Munsell', 'COMP311'),
#  ('Brent Munsell', 'COMP116'),
#  ('James Anderson', 'COMP737'),
#  ('James Anderson', 'COMP750'),
#  ('Danielle Szafir', 'COMP790-172'),
#  ('Daniel Szafir', 'COMP581'),
#  ('Parasara Sridhar Duggirala', 'COMP089'),
#  ('Parasara Sridhar Duggirala', 'COMP790-144'),
#  ('Praneeth Chakravarthula', 'COMP790-175'),
#  ('Ben Berg', 'COMP790-178'),
#  ('Shashank Srivastava', 'COMP664'),
#  ('Snigdha Chaturvedi', 'COMP790-158'),
#  ('Huaxiu Yao', 'COMP790-183'),
#  ('Andrew Kwong', 'COMP790-185'),
#  ('Mike Reed', 'COMP475'),
#  ('Paul Stotts', 'COMP590-59'),
#  ('Paul Stotts', 'COMP523'),
#  ('Prasun Dewan', 'COMP524'),
#  ('Jorge Silva', 'COMP562'),
#  ('Kris Jordan', 'COMP590-140'),
#  ('Junier Oliva', 'COMP755'),
#  ('TBD', 'COMP421')]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO QualifiedCourses (Prof, Course) VALUES (?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data4)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
data5 = []

for prof in profs:
    max_courses = prof_qs[prof]['max_classes']
    data5.append((prof, max_courses))

data5
# Out:
# [('Montek Singh', 1),
#  ('Tessa Joseph-Nicholas', 3),
#  ('Ketan Mayer-Patel', 1),
#  ('Prairie Goodwin', 2),
#  ('Sayeed Ghani', 2),
#  ('P.S. Thiagarajan', 2),
#  ('Jasleen Kaur', 0),
#  ('Saba Eskandarian', 1),
#  ('Ron Alterovitz', 1),
#  ('Cynthia Sturton', 1),
#  ('Marc Niethammer', 1),
#  ('Izzi Hinks', 2),
#  ('Samarjit Chakraborty', 2),
#  ('Donald Porter', 1),
#  ('John Majikes', 2),
#  ('Alyssa Byrnes', 2),
#  ('Gedas Bertasius', 1),
#  ('Roni Sengupta', 1),
#  ('Kevin Sun', 2),
#  ('Cece McMahon', 2),
#  ('Shahriar Nirjon', 1),
#  ('Jack Snoeyink', 1),
#  ('Brent Munsell', 2),
#  ('James Anderson', 2),
#  ('Danielle Szafir', 1),
#  ('Daniel Szafir', 1),
#  ('Parasara Sridhar Duggirala', 1),
#  ('Praneeth Chakravarthula', 1),
#  ('Ben Berg', 1),
#  ('Shashank Srivastava', 1),
#  ('Snigdha Chaturvedi', 1),
#  ('Huaxiu Yao', 1),
#  ('Andrew Kwong', 1),
#  ('Mike Reed', 1),
#  ('Paul Stotts', 3),
#  ('Prasun Dewan', 1),
#  ('Jorge Silva', 1),
#  ('Kris Jordan', 1),
#  ('Junier Oliva', 1),
#  ('TBD', 1)]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO MaxCourses (Prof, MaxCourses) VALUES (?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data5)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
course_data = {
  "COMP110": {
    "title": "COMP110 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 300},
      {"section_number": 2, "seat_capacity": 300},
      {"section_number": 3, "seat_capacity": 150},
      {"section_number": 4, "seat_capacity": 150}
    ]
  },
  "COMP116": {
    "title": "COMP116 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": None}
    ]
  },
  "COMP126": {
    "title": "COMP126 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 120}
    ]
  },
  "COMP210": {
    "title": "COMP210 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 210},
      {"section_number": 2, "seat_capacity": 210}
    ]
  },
  "COMP211": {
    "title": "COMP211 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 200},
      {"section_number": 2, "seat_capacity": 200}
    ]
  },
  "COMP227": {
    "title": "COMP227 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 30}
    ]
  },
  "COMP283": {
    "title": "COMP283/283H Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 204}
    ]
  },
  "COMP301": {
    "title": "COMP301 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 200},
      {"section_number": 2, "seat_capacity": 200}
    ]
  },
  "COMP311": {
    "title": "COMP311 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 225}
    ]
  },
  "COMP380": {
    "title": "COMP380 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP380H": {
    "title": "COMP380H Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 24}
    ]
  },
  "COMP421": {
    "title": "COMP421 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 200}
    ]
  },
  "COMP426": {
    "title": "COMP426 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 200}
    ]
  },
  "COMP431": {
    "title": "COMP431 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP433": {
    "title": "COMP433 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 75}
    ]
  },
  "COMP435": {
    "title": "COMP435 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 70}
    ]
  },
  "COMP455": {
    "title": "COMP455 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 125},
      {"section_number": 2, "seat_capacity": 125}
    ]
  },
  "COMP475": {
    "title": "COMP475 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP488": {
    "title": "COMP488 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": None}
    ]
  },
  "COMP520": {
    "title": "COMP520 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": None}
    ]
  },
  "COMP523": {
    "title": "COMP523 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP524": {
    "title": "COMP524 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP530": {
    "title": "COMP530 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 75}
    ]
  },
  "COMP533": {
    "title": "COMP533 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP537": {
    "title": "COMP537 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 90}
    ]
  },
  "COMP541": {
    "title": "COMP541 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 45},
      {"section_number": 2, "seat_capacity": 45}
    ]
  },
  "COMP545": {
    "title": "COMP545 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 25}
    ]
  },
  "COMP550": {
    "title": "COMP550 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 125},
      {"section_number": 2, "seat_capacity": 125}
    ]
  },
  "COMP560": {
    "title": "COMP560 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP562": {
    "title": "COMP562 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 75}
    ]
  },
  "COMP581": {
    "title": "COMP581 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP590-59": {
    "title": "COMP590-59 Class",
    "sections": [
      {"section_number": 59, "seat_capacity": 90}
    ]
  },
  "COMP590-139": {
    "title": "COMP590-139 Class",
    "sections": [
      {"section_number": 139, "seat_capacity": 10}
    ]
  },
  "COMP590-140": {
    "title": "COMP590-140 Class",
    "sections": [
      {"section_number": 140, "seat_capacity": 280}
    ]
  },
  "COMP590-158": {
    "title": "COMP590-158 Class",
    "sections": [
      {"section_number": 158, "seat_capacity": 4}
    ]
  },
  "COMP590-170": {
    "title": "COMP590-170 Class",
    "sections": [
      {"section_number": 170, "seat_capacity": 30}
    ]
  },
  "COMP590-172": {
    "title": "COMP590-172 Class",
    "sections": [
      {"section_number": 172, "seat_capacity": 30}
    ]
  },
  "COMP590-177": {
    "title": "COMP590-177 Class",
    "sections": [
      {"section_number": 177, "seat_capacity": 60}
    ]
  },
  "COMP730": {
    "title": "COMP730 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": None}
    ]
  },
  "COMP664": {
    "title": "COMP664 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 60}
    ]
  },
  "COMP737": {
    "title": "COMP737 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 30}
    ]
  },
  "COMP750": {
    "title": "COMP750 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 30}
    ]
  },
  "COMP755": {
    "title": "COMP755 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 30}
    ]
  },
  "COMP775": {
    "title": "COMP775 Class",
    "sections": [
      {"section_number": 1, "seat_capacity": 30}
    ]
  },
  "COMP790-139": {
    "title": "COMP790-139 Class",
    "sections": [
      {"section_number": 139, "seat_capacity": 20}
    ]
  },
  "COMP790-144": {
    "title": "COMP790-144 Class",
    "sections": [
      {"section_number": 144, "seat_capacity": 30}
    ]
  },
  "COMP790-148": {
    "title": "COMP790-148 Class",
    "sections": [
      {"section_number": 148, "seat_capacity": 25}
    ]
  },
  "COMP790-158": {
    "title": "COMP790-158 Class",
    "sections": [
        {"section_number": 185, "seat_capacity": 30}
    ]
},
"COMP915": {
    "title": "COMP915 Class",
    "sections": [
        {"section_number": 1, "seat_capacity": 20}
    ]
}
}

data6 = []

for course in course_data.keys():
  for section in course_data[course]['sections']:
    data6.append((course, course_data[course]['title'], section['section_number'], section['seat_capacity']))

data6
# Out:
# [('COMP110', 'COMP110 Class', 1, 300),
#  ('COMP110', 'COMP110 Class', 2, 300),
#  ('COMP110', 'COMP110 Class', 3, 150),
#  ('COMP110', 'COMP110 Class', 4, 150),
#  ('COMP116', 'COMP116 Class', 1, None),
#  ('COMP126', 'COMP126 Class', 1, 120),
#  ('COMP210', 'COMP210 Class', 1, 210),
#  ('COMP210', 'COMP210 Class', 2, 210),
#  ('COMP211', 'COMP211 Class', 1, 200),
#  ('COMP211', 'COMP211 Class', 2, 200),
#  ('COMP227', 'COMP227 Class', 1, 30),
#  ('COMP283', 'COMP283/283H Class', 1, 204),
#  ('COMP301', 'COMP301 Class', 1, 200),
#  ('COMP301', 'COMP301 Class', 2, 200),
#  ('COMP311', 'COMP311 Class', 1, 225),
#  ('COMP380', 'COMP380 Class', 1, 60),
#  ('COMP380H', 'COMP380H Class', 1, 24),
#  ('COMP421', 'COMP421 Class', 1, 200),
#  ('COMP426', 'COMP426 Class', 1, 200),
#  ('COMP431', 'COMP431 Class', 1, 60),
#  ('COMP433', 'COMP433 Class', 1, 75),
#  ('COMP435', 'COMP435 Class', 1, 70),
#  ('COMP455', 'COMP455 Class', 1, 125),
#  ('COMP455', 'COMP455 Class', 2, 125),
#  ('COMP475', 'COMP475 Class', 1, 60),
#  ('COMP488', 'COMP488 Class', 1, None),
#  ('COMP520', 'COMP520 Class', 1, None),
#  ('COMP523', 'COMP523 Class', 1, 60),
#  ('COMP524', 'COMP524 Class', 1, 60),
#  ('COMP530', 'COMP530 Class', 1, 75),
#  ('COMP533', 'COMP533 Class', 1, 60),
#  ('COMP537', 'COMP537 Class', 1, 90),
#  ('COMP541', 'COMP541 Class', 1, 45),
#  ('COMP541', 'COMP541 Class', 2, 45),
#  ('COMP545', 'COMP545 Class', 1, 25),
#  ('COMP550', 'COMP550 Class', 1, 125),
#  ('COMP550', 'COMP550 Class', 2, 125),
#  ('COMP560', 'COMP560 Class', 1, 60),
#  ('COMP562', 'COMP562 Class', 1, 75),
#  ('COMP581', 'COMP581 Class', 1, 60),
#  ('COMP590-59', 'COMP590-59 Class', 59, 90),
#  ('COMP590-139', 'COMP590-139 Class', 139, 10),
#  ('COMP590-140', 'COMP590-140 Class', 140, 280),
#  ('COMP590-158', 'COMP590-158 Class', 158, 4),
#  ('COMP590-170', 'COMP590-170 Class', 170, 30),
#  ('COMP590-172', 'COMP590-172 Class', 172, 30),
#  ('COMP590-177', 'COMP590-177 Class', 177, 60),
#  ('COMP730', 'COMP730 Class', 1, None),
#  ('COMP664', 'COMP664 Class', 1, 60),
#  ('COMP737', 'COMP737 Class', 1, 30),
#  ('COMP750', 'COMP750 Class', 1, 30),
#  ('COMP755', 'COMP755 Class', 1, 30),
#  ('COMP775', 'COMP775 Class', 1, 30),
#  ('COMP790-139', 'COMP790-139 Class', 139, 20),
#  ('COMP790-144', 'COMP790-144 Class', 144, 30),
#  ('COMP790-148', 'COMP790-148 Class', 148, 25),
#  ('COMP790-158', 'COMP790-158 Class', 185, 30),
#  ('COMP915', 'COMP915 Class', 1, 20)]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO CoursesAndSchedules (Course, Title, Section, SeatCapacity) VALUES (?, ?, ?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data6)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.

# %%
rooms = {
    "SN-0014": {
        "capacity": 128
    },
    "FB-F009": {
        "capacity": 86
    },
    "SN-0011": {
        "capacity": 66
    },
    "FB-F007": {
        "capacity": 50
    },
    "FB-F141": {
        "capacity": 50
    },
    "SN-0115": {
        "capacity": 25
    },
    "FB-F008": {
        "capacity": 20
    },
    "SN-0252": {
        "capacity": 20
    },
    "SN-0006": {
        "capacity": 15
    },
    "SN-0325": {
        "capacity": 15
    },
    "SN-0155": {
        "capacity": 14
    },
    "FB-F120": {
        "capacity": 12
    },
    "SN-0277": {
        "capacity": 10
    },
    "FB-F331": {
        "capacity": 16
    },
    "university": {
        "capacity": 250
    }
}

data7 = []
for room in rooms.keys():
    data7.append((room, rooms[room]['capacity']))

data7
# Out:
# [('SN-0014', 128),
#  ('FB-F009', 86),
#  ('SN-0011', 66),
#  ('FB-F007', 50),
#  ('FB-F141', 50),
#  ('SN-0115', 25),
#  ('FB-F008', 20),
#  ('SN-0252', 20),
#  ('SN-0006', 15),
#  ('SN-0325', 15),
#  ('SN-0155', 14),
#  ('FB-F120', 12),
#  ('SN-0277', 10),
#  ('FB-F331', 16),
#  ('university', 250)]

# %%
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

try:
    insert_query = "INSERT INTO Rooms (Room, SeatCapacity) VALUES (?, ?)"
    
    # Execute the query for each row of data
    cursor.executemany(insert_query, data7)
    print("Data inserted successfully.")

    # Commit the transaction
    connection.commit()
except sqlite3.Error as error:
    print(f"Error occurred: {error}")
finally:
    connection.close()
    print("Database connection closed.")
# Out:
# Data inserted successfully.
# Database connection closed.
